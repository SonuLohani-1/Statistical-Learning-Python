# %% [markdown]
# ### 2. Solutions
#
# a. Since we are mostly interested in knowing which data may affect the salary of CEO based on some parameters and not predicting the salary it is most like a classification problem rather than prediction problem. (Here if we would have been interesented in predicting the salary based on these parameters that would have been a prediction problem).
#
# b. This is most likely again a classification problem since we are looking to categorize things into success and failure (even though it is prediction about future, we are not interested in knowing some numerical values these are just two classes).
#
# c. This is a prediction problem since we want to predict the numerical values of the exchange rates based on given parameters.

# %% [markdown]
# ### 2. Solutions:
#
# a. n = 500, p = 4 (profit, number of employees, industry, CEO salary)
# Since we are interested in interested in just what affects the CEO's salary so it is a inference and not a prediction problem. Also the response will be qualtitative and not quantitative it is a classification problem not a regression problem.
#
# b. n = 20, p = 14.
# Since we are interested in predicting whether a product will be a success or failure it is a prediction problem. Also the response will be qualititative (either success or failure) it is a classification problem and not a regression problem.
#
# c. n = 52 (no. of weeks in a year), p = 4
# This is a prediction problem. Also we are interested in the quantitative value so it is a regression problem.
