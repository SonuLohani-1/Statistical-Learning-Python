# %% [markdown]
# ### 4 Solution:
#
# a. Three real world examples of classifications can be as follows:
#
# (i) We want to categorize customers into categories based on spending habits. Response could be something like High spenders, Medium spenders, Low spenders. Predictors can be age, avg monthly spending values of past, profession, area of living, device type etc. The goal here is inference.
#
# (ii) Divide a person into diabetes risk categories based on their daily routines. Response could be high , low, medium. Predictors can be family history, age, weight, profession, activity levels. Here the goal is inference.
#
# (iii) Predict whether a student will pass or fail an tough entrance exam (like jee advanced) based on their weekly test scores, IQ, daily study hours. Here the goal is prediction.

# %% [markdown]
# Corrections:
#
# (i). The goal is prediction not inference which I have written incorrectly.
# (ii). Again the goal here is prediction not inference.

# %% [markdown]
# b. Three real world example of regression problem can be as follows:
#
# (i) We want to predict how much should be the credit limit of a customers. Predictors can be spending amount, profession, salary, monthly spending values, past credit history etc. The problem is a prediction problem here.
# (ii) We want to know how much chance of diabetes a person has. Predictors can be family history, age, weight, profession activity level, eating habits etc. This is again a prediction problem.
# (iii) Predicting the score or rank of a student in a tough entrance exam  based on their weekly test scores, IQ, daily study hours etc. Here again the goal is prediction.

# %% [markdown]
# Corrections:
#
# (ii) This is still a classification problem with probability. The better example would be predicting blood sugar level based on the factors mentioned.
#
# One example of regression + inference:
#
# Scenario: Economics research on the relationship between education and income.
#
# Response: Annual income (numerical, in $) → Regression
#
# Predictors: Years of education, years of work experience, gender, region, job sector
#
# Goal: Inference

# %% [markdown]
# c. Three real life applications where cluster analysis might be helpful:
# (i) We want to know if there is some clustering among the customers spending and different variable like area, income, salary.
# (ii) We want to study if the tumor separates into different cateogries like benign or malign based on sizes and other aspects.
# (iii) Study clusters of students weekly test scores with different variables like parents earning, education levels and parents profession.

# %% [markdown]
# Corrections:
#
# (i) Better Framing: We want to segment customers into groups based on their spending behavior, income, location, and profession. Clustering helps discover natural groupings like “budget shoppers,” “luxury spenders,” etc., which can be used for personalized marketing.
#
# (ii) Incorrect there can't be predefined categories like benign or malignent then it will be a classification problem. We want to explore whether tumors naturally group into subtypes based on measurements like size, texture, cell count, and growth rate — without knowing if they're benign or malignant.
#
# (iii)Better Framing: We want to cluster students based on weekly test performance, study hours, and socioeconomic background (e.g., parents’ income, education, profession) to identify different learning profiles or risk groups.
