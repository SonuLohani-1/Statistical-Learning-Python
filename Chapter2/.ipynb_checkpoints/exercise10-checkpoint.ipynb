# %%
import ISLP
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 10 (a)

# %%
boston_data = ISLP.load_data("Boston")
boston_data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %% [markdown]
# (b)

# %% [markdown]
# There are 506 row and 13 columns.
# Columns here represent different features that are present in the data collectd like for a group of people.
# Rows represent different sample in the data.

# %% [markdown]
# (c)

# %%
boston_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  lstat    506 non-null    float64
#  12  medv     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
boston_data.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
sns.pairplot(boston_data, diag_kind="kde")

# %% [markdown]
# (d)

# %%
sns.pairplot(boston_data, y_vars="crim")

# %% [markdown]
# Yes some of the predictors are association with crim (per capita crime rate):
# (i) most of the higher crim are associated with indus value of around 18-19
# (ii) more crim value is there for chas = 0 than chas = 1
# (iii) most high crim values are for nox around 0.55-0.75
# (iv) for rm the data distribution is kind of normal.
# (v) as expected more high crim values are there for age above 50 and most high values are for age above 75.
# (vi) most of the high crim values are concentrated in the dis 0 to 5.0
# (vii) most high crim values are associated with rad value around 25,
# (vii) most high crim values are assoiciate with tax values around 650-700.
# (viii) most high crim values are associated with ptratio of 20.
# (x) the crim values generally increasing with lstat.
# (xi) crim values generally decreasing with medv

# %% [markdown]
# (e)

# %%
sns.scatterplot(data=boston_data, x = "zn", y = "crim")
# Out:
# <Axes: xlabel='zn', ylabel='crim'>

# %%
sns.scatterplot(data=boston_data, x = "zn", y = "tax")
# Out:
# <Axes: xlabel='zn', ylabel='tax'>

# %%
sns.scatterplot(data=boston_data, x="zn", y="ptratio")
# Out:
# <Axes: xlabel='zn', ylabel='ptratio'>

# %% [markdown]
# Based on the 3 plots shown above we can only know that zn = 0 has high values of crim (per capita crime rate) and highest tax rate as well.
# Also zn = 20 has highest pt ratio of 80.

# %% [markdown]
# (f)

# %%
boston_data["chas"].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# (g)

# %%
boston_data["ptratio"].median()
# Out:
# np.float64(19.05)

# %% [markdown]
# (h)

# %%
boston_data.pivot_table(index=["medv"], sort=True)
# Out:
#              age   chas       crim       dis      indus      lstat       nox  \
# medv
# 5.0   100.000000  0.000  53.136300  1.457500  18.100000  26.785000  0.693000
# 5.6   100.000000  0.000  25.046100  1.588800  18.100000  26.770000  0.693000
# 6.3    77.800000  0.000   9.916550  1.500400  18.100000  29.970000  0.693000
# 7.0    99.150000  0.000  22.964735  1.706800  22.920000  30.475000  0.651000
# 7.2    99.366667  0.000  16.377533  1.611633  18.100000  26.726667  0.690667
# ...          ...    ...        ...       ...        ...        ...       ...
# 46.7   17.000000  0.000   0.298190  3.375100   6.200000   3.920000  0.504000
# 48.3   70.400000  0.000   0.331470  3.651900   6.200000   3.950000  0.507000
# 48.5   33.200000  0.000   0.035100  5.118000   2.680000   3.810000  0.416100
# 48.8   91.500000  0.000   0.520140  2.288500   3.970000   5.910000  0.647000
# 50.0   77.637500  0.375   2.703412  2.586088  11.860625   4.355000  0.566569
#
# ...

# %% [markdown]
# (i)

# %%
boston_data[boston_data["rm"] > 7]
# Out:
#          crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 2     0.02729   0.0   7.07     0  0.4690  7.185  61.1  4.9671    2  242
# 4     0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622    3  222
# 40    0.03359  75.0   2.95     0  0.4280  7.024  15.8  5.4011    3  252
# 55    0.01311  90.0   1.22     0  0.4030  7.249  21.9  8.6966    5  226
# 64    0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229    3  216
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...  ...
# 364   3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047   24  666
# 370   6.53876   0.0  18.10     1  0.6310  7.016  97.5  1.2024   24  666
# 375  19.60910   0.0  18.10     0  0.6710  7.313  97.9  1.3163   24  666
# 453   8.24809   0.0  18.10     0  0.7130  7.393  99.3  2.4527   24  666
# 482   5.73116   0.0  18.10     0  0.5320  7.061  77.0  3.4106   24  666
#
#      ptratio  lstat  medv
# 2       17.8   4.03  34.7
# 4       18.7   5.33  36.2
# ...
