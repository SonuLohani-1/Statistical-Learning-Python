# %% [markdown]
# ### 7. Solution:
# (a) Distances with different observations: 3, 2, sqrt(10), sqrt(5), sqrt(2), sqrt(3)
# (b) With k = 1, the prediction will be Green (since the least distance is sqrt(2) with 5th observation)
# (c) With k = 3, the prediction will be Red(since among 3 nearest neighbours 2 are red).
# (d) If Bayes decision boundary is highly non-linear means we will need flexibility so taking the smaller value of K will be better.
