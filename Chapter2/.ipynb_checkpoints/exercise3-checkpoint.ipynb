# %% [markdown]
# ### 3. Solution
# b.
# (i) Squared bias will keep on decreasing as we keep on increasing the flexibility and will reach to a certain value after sometime.
# (ii) Variance will first decrease reach a minimum value and then it will keep on increasing.
# (iii) Training error will keep on decreasing as we will keep on increasing the flexibility (although it will reach to a certain minimum value when all the points are completely fit).
# (iv) Test error will first decrease and will reach to a minimum value and then it will start rising again.
# (v) Irreducible error will always be same since it is irreducible.

# %% [markdown]
# Some corrections after checking:
# (i) Squared bias will keep on decreasing very slowly for always.
# (ii) Variance will never decrease it will always increase with the flexibility.
