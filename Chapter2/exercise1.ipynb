# %% [markdown]
# ### 1. My Solution:
#
# (a) We can't state much just based on the number of less parameters because if the actual model is complex then then a less flexible model will have a high bias but if the model is simple (like linear) than a more flexible model will have high variance. But since the parameters are still less, assuming that the less flexible model is better here then I think that the less flexile model will perform better.
#
# (b) Here as opposed to the reason in a since (a) since a more flexible model will have high variance (because we have relatively small number of samples) I think a less flexible model will work better.
#
# (c) Since the relation is non linear given we will expect a more flexible model to perform better.
#
# (d) Since the variance of the error term is high a more flexible model will take into account this as well so I will expect a less flexible model to behave far better.

# %% [markdown]
# ### 1. Actual Solution:
#
# (a) Since the number of parameters are less and n is extremely large a flexible model will generally perform better since it will capture more patterns and because of more number of data points variance will be reduced.
#
# (b) My answer is correct because of fewer observations there will be overfitting.
#
# (c) My answer is correct
#
# (d) My answer is correct
