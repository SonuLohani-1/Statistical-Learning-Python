# %% [markdown]
# Solution:
#
# The null hypothesis to which the p-value given in Table 3.4 corresponds is as follows:
# "The regression coefficent associated with advertisement spending of corresponding media (TV, Radio, Newspaper) is 0, i.e, there is no effect on sales by increasing advertisement spending on that media while keeping advertisement spending on other media the same."
#
# The following are the p-values of different media:
# TV: < 0.0001
# Radio: < 0.0001
# Newspaper: 0.8599
#
# From the p-values, we can see that we have enough evidence to discard the null hypothesis for TV and Radio. But for Newspaper, the p-value is quite large, so we can see that there is not enough evidence that any advertisement spending on Newspaper (for a given amount of TV and Radio spending) will increase any sales.

# %% [markdown]
# Better Version (Optimized using ChatGPT):
#
# The p-values in Table 3.4 test the null hypothesis that the true coefficient of each advertising medium (TV, radio, newspaper) is zero. In practical terms, this means testing whether spending on that medium has no effect on product sales, assuming spending on the other two media remains constant.
#
# From the table:
#
# TV (p < 0.0001): Strong evidence that TV advertising significantly increases sales.
#
# Radio (p < 0.0001): Strong evidence that radio advertising significantly increases sales.
#
# Newspaper (p = 0.8599): No evidence that newspaper advertising affects sales.
#
# Therefore, we conclude that only TV and radio advertising have a statistically significant impact on sales, while newspaper advertising does not.
