# %% [raw]
# We will generate multiple bootstrap datasets from the original training dataset. For each of the bootstrap datasets, we will fit a model. Now, for each of the models, we will get the predicted value for the point of interest. Based on all the predictions, we can calculate the standard deviation for our prediction.
