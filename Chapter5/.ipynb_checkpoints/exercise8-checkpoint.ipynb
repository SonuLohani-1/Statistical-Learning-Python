# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import (cross_validate, KFold, ShuffleSplit)

# %%
from ISLP.models import (ModelSpec as MS, poly, summarize)
from ISLP.models import sklearn_sm

# %% [markdown]
# # (a)

# %%
rng = np.random.default_rng(1)
x = rng.normal(size=100)
y = x - 2*x**2 + rng.normal(size=100)

# %% [markdown]
# Here n = 100, and p = 1 since only one single column predictor x is there.

# %%
fig, ax = plt.subplots()
ax.scatter(x, y)
ax.set_xlabel("X")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Based on the graph, the relationship between X and y appears to be non-linear in nature.

# %% [markdown]
# # (c)

# %%
df = pd.DataFrame({"X": x, "y":y})
df
# Out:
#            X          y
# 0   0.345584  -0.544554
# 1   0.821618   0.333950
# 2   0.330437  -0.013532
# 3  -1.303157  -4.030442
# 4   0.905356   0.484861
# ..       ...        ...
# 95 -2.250854 -14.001012
# 96 -0.138655   0.932532
# 97  0.033000   0.198928
# 98 -1.425349  -4.940183
# 99  0.332814  -0.953841
#
# [100 rows x 2 columns]

# %%
# (i)
model = sklearn_sm(sm.OLS, MS(['X']))
X, y = df.drop(columns=['y']), df['y']
cv_results = cross_validate(model, X, y, cv=df.shape[0])
cv_results
# Out:
# {'fit_time': array([0.00372553, 0.00354862, 0.00395036, 0.00394535, 0.00361323,
#         0.00357962, 0.00339246, 0.00386691, 0.00408196, 0.00318646,
#         0.00356364, 0.0031445 , 0.00318003, 0.00408196, 0.00465608,
#         0.00357318, 0.00303674, 0.00299883, 0.00373125, 0.00338578,
#         0.00311422, 0.00320649, 0.00333834, 0.00358248, 0.00399613,
#         0.00327063, 0.00316715, 0.00313902, 0.00331759, 0.00394344,
#         0.0030303 , 0.00302601, 0.0031507 , 0.00299549, 0.0028708 ,
#         0.00325251, 0.00325513, 0.00347042, 0.00327063, 0.00320578,
#         0.00359774, 0.00354671, 0.00321054, 0.00302887, 0.00323296,
#         0.00361037, 0.00321269, 0.00298309, 0.00325203, 0.00373435,
#         0.00344801, 0.00325847, 0.00298333, 0.00328875, 0.00329924,
#         0.00303507, 0.0031743 , 0.00347972, 0.00384402, 0.0037365 ,
#         0.00332808, 0.00307751, 0.00323367, 0.00339556, 0.00319338,
#         0.00300145, 0.00316143, 0.00363946, 0.00319195, 0.00292897,
# ...

# %%
# (ii)
# design = MS([poly("x", degree=2)])
# X = design.fit_transform(df)
# model = sklearn_sm(sm.OLS, design)
# cv_results = cross_validate(design, X, y, cv=df.shape[0])
# cv_results
from sklearn.model_selection import LeaveOneOut
design = MS([poly("X", degree=2)])
model = sklearn_sm(sm.OLS, design)
X, y = df[['X']], df['y']

loo = LeaveOneOut()

cv_results = cross_validate(model, X, y)
cv_results
# Out:
# /home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/ISLP/models/sklearn_wrap.py", line 113, in score
#     yhat = self.predict(X)
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/ISLP/models/sklearn_wrap.py", line 88, in predict
#     X = self.model_spec_.transform(X)
# ...

# %%
df = pd.DataFrame({'x': x, 'y': y})
design = MS([poly('x', degree=2)])
model = sklearn_sm(sm.OLS, design)
cv_results = cross_validate(model, df[['x']], df['y'], cv=df.shape[0])
cv_results
# Out:
# /home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/ISLP/models/sklearn_wrap.py", line 113, in score
#     yhat = self.predict(X)
#   File "/home/sonu/miniconda3/envs/islp/lib/python3.13/site-packages/ISLP/models/sklearn_wrap.py", line 88, in predict
#     X = self.model_spec_.transform(X)
# ...

# %%
X
# Out:
#     intercept  poly(x, degree=2)[0]  poly(x, degree=2)[1]
# 0         1.0              0.049227             -0.036584
# 1         1.0              0.105129              0.034593
# 2         1.0              0.047448             -0.038177
# 3         1.0             -0.144388              0.032896
# 4         1.0              0.114962              0.051342
# ..        ...                   ...                   ...
# 95        1.0             -0.255678              0.294791
# 96        1.0             -0.007638             -0.067043
# 97        1.0              0.012520             -0.061085
# 98        1.0             -0.158737              0.057565
# 99        1.0              0.047727             -0.037930
#
# [100 rows x 3 columns]

# %%
design
# Out:
# ModelSpec(terms=[Feature(variables=('x',), name='poly(x, degree=2)', encoder=Poly(degree=2), use_transform=True, pure_columns=False, override_encoder_colnames=True)])

# %%
cross_validate?
# Out:
# Signature:
# cross_validate(
#     estimator,
#     X,
#     y=None,
#     *,
#     groups=None,
#     scoring=None,
#     cv=None,
#     n_jobs=None,
#     verbose=0,
#     params=None,
#     pre_dispatch='2*n_jobs',
#     return_train_score=False,
#     return_estimator=False,
#     return_indices=False,
#     error_score=nan,
# )
# Docstring:
# Evaluate metric(s) by cross-validation and also record fit/score times.
#
# Read more in the :ref:`User Guide <multimetric_cross_validation>`.
#
# Parameters
# ----------
# estimator : estimator object implementing 'fit'
#     The object to use to fit the data.
#
# X : {array-like, sparse matrix} of shape (n_samples, n_features)
#     The data to fit. Can be for example a list, or an array.
#
# y : array-like of shape (n_samples,) or (n_samples, n_outputs), default=None
#     The target variable to try to predict in the case of
#     supervised learning.
#
# groups : array-like of shape (n_samples,), default=None
# ...
