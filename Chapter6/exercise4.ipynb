# %% [markdown]
# # (a)

# %% [markdown]
# At lambda = 0, the training RSS is same as for OLS, as we increase the lambda the coefficients get shrunk, so the model becomes more constrained and fits training data worse. As, a result the training RSS increases. So, option (iii) is correct.

# %% [markdown]
# # (b)

# %% [markdown]
# At lambda = 0, the model is slightly overfit, as we increase the lambda, the test RSS decrease and  the model reaches an optimal point. After that because of underfitting, the bias increases so test RSS again starts increasing. So, option (ii) is correct.

# %% [markdown]
# # (c)

# %% [markdown]
# The variance keeps on decreasing the model becomes underfit as the lambda increases. So, option (iv) is correct.

# %% [markdown]
# # (d)

# %% [markdown]
# The bias keeps on increasing as coeffiecients starts decreasing when we increasing the lambda. So, option (iii) is correct.

# %% [markdown]
# # (e)

# %% [markdown]
# Irreducible error is independent of lambda, so it remains constant.so, option (v) is correct.
