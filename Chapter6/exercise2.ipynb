# %% [markdown]
# # (a)

# %% [markdown]
# The lasso is less flexible compared to least square so there is an increase in bias and decrease in variance. So, the lasso is only effective when increase in bias is less than its decrease in variance. So only (iii) is correct and others are false.

# %% [markdown]
# # (b)

# %% [markdown]
# Ridge Regression also has similar case as lasso. So, again only (iii) is correct.

# %% [markdown]
# # (c)

# %% [markdown]
# The non-linear model are more flexible compared to least squares, so there will an increase in variance and decrease in bias. So, it will give improved prediction only when the increase in variance is less than the decrease in bias. So option (ii) is true and others are false.
