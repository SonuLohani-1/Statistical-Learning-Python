# %% [markdown]
# # (a)

# %% [markdown]
# As s increases from 0, the constraint relaxes, giving the model more flexibility to fit the training data. Training RSS can only decrease or stay the same, it never increases because OLS already minimizes it. So training RSS steadily decreases. Answer: iv

# %% [markdown]
# # (b)

# %% [markdown]
# At, s = 0, all beta_j = 0, so the model is underfit and the RSS is high. As s increases, because of flexibility the RSS starts decreasing. But after a point, the model starts overfitting the training data so the test RSS starts increasing again, so we get a U shape because of bias-variation tradeoff. Answer: ii

# %% [markdown]
# # (c)

# %% [markdown]
#  Variance keeps on increasing as the model goes from underfit to overfit. Answer: iii

# %% [markdown]
# # (d)

# %% [markdown]
# As s increases the constrained on parameters relaxes, so bias steadily decreases.

# %% [markdown]
# # (e)
