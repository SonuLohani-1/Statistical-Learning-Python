# %% [markdown]
# # (a)

# %% [markdown]
# Since best subset selection always selects the best model for any no. of parameters, it has the smallest training RSS among the three models.

# %% [markdown]
# ## (b)

# %% [markdown]
# Since, the training and test RSS are different we can't say in general which one will give the better test RSS.

# %% [markdown]
# # (c)

# %% [markdown]
# Only (i) and (ii) are True and other are False.
# Reason: In Forward or Backward Selection process, the model is selected by adding a predictor to a smaller model or removing a predictor from the bigger model. So, the smaller model will always be a subset of the bigger model.
# This is not the case in best subset selection where every model of any size independent from larger (or smaller) sized models.
